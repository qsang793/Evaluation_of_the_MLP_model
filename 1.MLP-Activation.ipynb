# %%
import tensorflow as tf
from tensorflow import keras

# Data Preparation
(train_images, train_labels), (test_images, test_labels) = keras.datasets.cifar10.load_data()

# Data Normalization [0,1]
train_images = train_images / 255.0
test_images = test_images / 255.0
# Out:
# ...
# 170498071/170498071 [==============================] - 4s 0us/step

# %%
# model
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(32,32,3)),
    keras.layers.Dense(128, activation='sigmoid'),
    keras.layers.Dense(128, activation='sigmoid'),
    keras.layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history_data = model.fit(train_images, train_labels,
                    validation_data=(test_images, test_labels),
                    batch_size=1024, epochs=80, verbose=2)
# Out:
# Epoch 1/80
# 49/49 - 3s - loss: 2.2453 - accuracy: 0.1860 - val_loss: 2.1297 - val_accuracy: 0.2576 - 3s/epoch - 63ms/step
# Epoch 2/80
# 49/49 - 0s - loss: 2.0318 - accuracy: 0.2794 - val_loss: 1.9548 - val_accuracy: 0.2907 - 486ms/epoch - 10ms/step
# Epoch 3/80
# 49/49 - 0s - loss: 1.9095 - accuracy: 0.3201 - val_loss: 1.8707 - val_accuracy: 0.3395 - 487ms/epoch - 10ms/step
# Epoch 4/80
# 49/49 - 0s - loss: 1.8374 - accuracy: 0.3506 - val_loss: 1.8174 - val_accuracy: 0.3572 - 484ms/epoch - 10ms/step
# Epoch 5/80
# 49/49 - 0s - loss: 1.7901 - accuracy: 0.3681 - val_loss: 1.7628 - val_accuracy: 0.3825 - 469ms/epoch - 10ms/step
# Epoch 6/80
# 49/49 - 0s - loss: 1.7401 - accuracy: 0.3849 - val_loss: 1.7274 - val_accuracy: 0.3897 - 462ms/epoch - 9ms/step
# Epoch 7/80
# 49/49 - 0s - loss: 1.7035 - accuracy: 0.3986 - val_loss: 1.6883 - val_accuracy: 0.4116 - 465ms/epoch - 9ms/step
# Epoch 8/80
# ...

# %%
# model
model2 = keras.Sequential([
    keras.layers.Flatten(input_shape=(32,32,3)),
    keras.layers.Dense(128, activation='sigmoid'),
    keras.layers.Dense(128, activation='sigmoid'),
    keras.layers.Dense(128, activation='sigmoid'),
    keras.layers.Dense(128, activation='sigmoid'),
    keras.layers.Dense(128, activation='sigmoid'),
    keras.layers.Dense(10, activation='softmax')
])

model2.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history_data2 = model2.fit(train_images, train_labels,
                    validation_data=(test_images, test_labels),
                    batch_size=1024, epochs=80, verbose=2)
# Out:
# Epoch 1/80
# 49/49 - 3s - loss: 2.3179 - accuracy: 0.1011 - val_loss: 2.2872 - val_accuracy: 0.0953 - 3s/epoch - 53ms/step
# Epoch 2/80
# 49/49 - 1s - loss: 2.1698 - accuracy: 0.1624 - val_loss: 2.0735 - val_accuracy: 0.1853 - 578ms/epoch - 12ms/step
# Epoch 3/80
# 49/49 - 1s - loss: 2.0568 - accuracy: 0.1904 - val_loss: 2.0408 - val_accuracy: 0.1988 - 501ms/epoch - 10ms/step
# Epoch 4/80
# 49/49 - 1s - loss: 2.0298 - accuracy: 0.1963 - val_loss: 2.0164 - val_accuracy: 0.2034 - 517ms/epoch - 11ms/step
# Epoch 5/80
# 49/49 - 0s - loss: 2.0126 - accuracy: 0.2005 - val_loss: 1.9950 - val_accuracy: 0.2075 - 491ms/epoch - 10ms/step
# Epoch 6/80
# 49/49 - 1s - loss: 1.9940 - accuracy: 0.2048 - val_loss: 1.9916 - val_accuracy: 0.2066 - 585ms/epoch - 12ms/step
# Epoch 7/80
# 49/49 - 1s - loss: 1.9810 - accuracy: 0.2118 - val_loss: 1.9614 - val_accuracy: 0.2246 - 505ms/epoch - 10ms/step
# Epoch 8/80
# ...

# %%
# model
model3 = keras.Sequential([
    keras.layers.Flatten(input_shape=(32,32,3)),
    keras.layers.Dense(128, activation='tanh'),
    keras.layers.Dense(128, activation='tanh'),
    keras.layers.Dense(10, activation='softmax')
])

model3.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history_data3 = model3.fit(train_images, train_labels,
                    validation_data=(test_images, test_labels),
                    batch_size=1024, epochs=80, verbose=2)
# Out:
# Epoch 1/80
# 49/49 - 2s - loss: 2.1769 - accuracy: 0.2130 - val_loss: 1.9399 - val_accuracy: 0.2960 - 2s/epoch - 39ms/step
# Epoch 2/80
# 49/49 - 0s - loss: 1.8785 - accuracy: 0.3261 - val_loss: 1.8299 - val_accuracy: 0.3464 - 457ms/epoch - 9ms/step
# Epoch 3/80
# 49/49 - 1s - loss: 1.7917 - accuracy: 0.3627 - val_loss: 1.7609 - val_accuracy: 0.3781 - 536ms/epoch - 11ms/step
# Epoch 4/80
# 49/49 - 0s - loss: 1.7404 - accuracy: 0.3800 - val_loss: 1.7425 - val_accuracy: 0.3826 - 450ms/epoch - 9ms/step
# Epoch 5/80
# 49/49 - 1s - loss: 1.6938 - accuracy: 0.3958 - val_loss: 1.6769 - val_accuracy: 0.4119 - 526ms/epoch - 11ms/step
# Epoch 6/80
# 49/49 - 0s - loss: 1.6541 - accuracy: 0.4127 - val_loss: 1.6404 - val_accuracy: 0.4188 - 455ms/epoch - 9ms/step
# Epoch 7/80
# 49/49 - 0s - loss: 1.6194 - accuracy: 0.4277 - val_loss: 1.6252 - val_accuracy: 0.4211 - 457ms/epoch - 9ms/step
# Epoch 8/80
# ...

# %%
# model
model4 = keras.Sequential([
    keras.layers.Flatten(input_shape=(32,32,3)),
    keras.layers.Dense(128, activation='tanh'),
    keras.layers.Dense(128, activation='tanh'),
    keras.layers.Dense(128, activation='tanh'),
    keras.layers.Dense(128, activation='tanh'),
    keras.layers.Dense(128, activation='tanh'),
    keras.layers.Dense(10, activation='softmax')
])

model4.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

history_data4 = model4.fit(train_images, train_labels,
                    validation_data=(test_images, test_labels),
                    batch_size=1024, epochs=80, verbose=2)
# Out:
# Epoch 1/80
# 49/49 - 3s - loss: 2.0751 - accuracy: 0.2305 - val_loss: 1.8952 - val_accuracy: 0.3121 - 3s/epoch - 51ms/step
# Epoch 2/80
# 49/49 - 1s - loss: 1.8255 - accuracy: 0.3434 - val_loss: 1.7501 - val_accuracy: 0.3744 - 575ms/epoch - 12ms/step
# Epoch 3/80
# 49/49 - 1s - loss: 1.7330 - accuracy: 0.3776 - val_loss: 1.6914 - val_accuracy: 0.3941 - 505ms/epoch - 10ms/step
# Epoch 4/80
# 49/49 - 1s - loss: 1.6714 - accuracy: 0.4027 - val_loss: 1.6709 - val_accuracy: 0.4001 - 585ms/epoch - 12ms/step
# Epoch 5/80
# 49/49 - 0s - loss: 1.6559 - accuracy: 0.4066 - val_loss: 1.6409 - val_accuracy: 0.4213 - 493ms/epoch - 10ms/step
# Epoch 6/80
# 49/49 - 1s - loss: 1.5957 - accuracy: 0.4295 - val_loss: 1.6011 - val_accuracy: 0.4264 - 505ms/epoch - 10ms/step
# Epoch 7/80
# 49/49 - 1s - loss: 1.5709 - accuracy: 0.4408 - val_loss: 1.5776 - val_accuracy: 0.4414 - 519ms/epoch - 11ms/step
# Epoch 8/80
# ...

# %%
# prompt: Vẽ 4 đồ thị trên 1 hàng, 2 đồ thị loss cho tập train và test 2 đồ thị accuracy cho train và test trên bộ dữ liệu Fashion MNIST với 4 history_data vừa thu được

import matplotlib.pyplot as plt

# Create a figure with 2 rows and 2 columns of subplots
fig, axs = plt.subplots(2, 2, figsize=(15, 15))

# Plot the loss for the first model on the first subplot
axs[0, 0].plot(history_data.history['loss'], label='Train Loss')
axs[0, 0].plot(history_data.history['val_loss'], label='Test Loss')
axs[0, 0].set_title('Model 1 - Loss')
axs[0, 0].set_xlabel('Epoch')
axs[0, 0].set_ylabel('Loss')
axs[0, 0].legend()

# Plot the accuracy for the first model on the second subplot
axs[0, 1].plot(history_data.history['accuracy'], label='Train Accuracy')
axs[0, 1].plot(history_data.history['val_accuracy'], label='Test Accuracy')
axs[0, 1].set_title('Model 1 - Accuracy')
axs[0, 1].set_xlabel('Epoch')
axs[0, 1].set_ylabel('Accuracy')
axs[0, 1].legend()

# Plot the loss for the second model on the third subplot
axs[1, 0].plot(history_data2.history['loss'], label='Train Loss')
axs[1, 0].plot(history_data2.history['val_loss'], label='Test Loss')
axs[1, 0].set_title('Model 2 - Loss')
axs[1, 0].set_xlabel('Epoch')
axs[1, 0].set_ylabel('Loss')
axs[1, 0].legend()

# Plot the accuracy for the second model on the fourth subplot
axs[1, 1].plot(history_data2.history['accuracy'], label='Train Accuracy')
axs[1, 1].plot(history_data2.history['val_accuracy'], label='Test Accuracy')
axs[1, 1].set_title('Model 2 - Accuracy')
axs[1, 1].set_xlabel('Epoch')
axs[1, 1].set_ylabel('Accuracy')
axs[1, 1].legend()

# Adjust the spacing between subplots
plt.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Create a figure with 2 rows and 2 columns of subplots
fig, axs = plt.subplots(1, 4, figsize=(20, 5))
# summarize history for loss
axs[0].plot(history_data.history['loss'], label='sigmoid_2_layer_train_loss')
axs[0].plot(history_data2.history['loss'], label='sigmoid_5_layer_train_loss')
axs[0].plot(history_data3.history['loss'], label='tanh_2_layer_train_loss')
axs[0].plot(history_data4.history['loss'], label='tanh_5_layer_train_loss')
axs[0].set_title('Train loss')
axs[0].set_ylabel('Loss')
axs[0].set_xlabel('Epoch')
axs[0].legend()

# Summarize history for testing loss
axs[1].plot(history_data.history['val_loss'], label='sigmoid_2_layer_test_loss')
axs[1].plot(history_data2.history['val_loss'], label='sigmoid_5_layer_test_loss')
axs[1].plot(history_data3.history['val_loss'], label='tanh_2_layer_test_loss')
axs[1].plot(history_data4.history['val_loss'], label='tanh_5_layer_test_loss')
axs[1].set_title('Test Loss')
axs[1].set_ylabel('Loss')
axs[1].set_xlabel('Epoch')
axs[1].legend()

# Summarize history for training accuracy
axs[2].plot(history_data.history['accuracy'], label='sigmoid_2_layer_train_accuracy')
axs[2].plot(history_data2.history['accuracy'], label='sigmoid_5_layer_train_accuracy')
axs[2].plot(history_data3.history['accuracy'], label='tanh_2_layer_train_accuracy')
axs[2].plot(history_data4.history['accuracy'], label='tanh_5_layer_train_accuracy')
axs[2].set_title('Train Accuracy')
axs[2].set_ylabel('Accuracy')
axs[2].set_xlabel('Epoch')
axs[2].legend()

# Summarize history for testing accuracy
axs[3].plot(history_data.history['val_accuracy'], label='sigmoid_2_layer_test_accuracy')
axs[3].plot(history_data2.history['val_accuracy'], label='sigmoid_5_layer_test_accuracy')
axs[3].plot(history_data3.history['val_accuracy'], label='tanh_2_layer_test_accuracy')
axs[3].plot(history_data4.history['val_accuracy'], label='tanh_5_layer_test_accuracy')
axs[3].set_title('Test Accuracy')
axs[3].set_ylabel('Accuracy')
axs[3].set_xlabel('Epoch')
axs[3].legend()

# Display the plot
plt.tight_layout()
plt.show()
